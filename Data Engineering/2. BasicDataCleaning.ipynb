# %%
import pandas as pd
import ast
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
import numpy as np
import json
import gc
from datetime import datetime
import re

# %% [markdown]
# # 1. Read dataset

# %%
rawdata_tourist_attraction = pd.read_excel(r"C:\Users\Ong Hui Ling\Dropbox\PC\Documents\Github\AI-Driven-Tourism-Recommendation-System\Dataset\TourismRawData.xlsx", sheet_name="Tourist Attractions")
rawdata_tourist_attraction['category'] = "Tourist Attractions"

# %%
rawdata_restaurant = pd.read_excel(r"C:\Users\Ong Hui Ling\Dropbox\PC\Documents\Github\AI-Driven-Tourism-Recommendation-System\Dataset\TourismRawData.xlsx", sheet_name="Restaurant")
rawdata_restaurant['category'] = "Restaurant"

# %%
rawdata_hotel = pd.read_excel(r"C:\Users\Ong Hui Ling\Dropbox\PC\Documents\Github\AI-Driven-Tourism-Recommendation-System\Dataset\TourismRawData.xlsx", sheet_name="Hotel")
rawdata_hotel['category'] = "Hotel"

# %% [markdown]
# # 2. Remove duplicates based on place id

# %%
# Combine tourist attraction, restaurant, and hotel data into one DataFrame
df = pd.concat([rawdata_tourist_attraction, rawdata_restaurant, rawdata_hotel], ignore_index=True)

# Remove duplicates based on 'place_id'
df = df.drop_duplicates(subset='place_id', keep='first')

# %%
df.shape
# Out:
# (7306, 15)

# %% [markdown]
# # 3. Split reviews in json format into 5 separate rows

# %%
# Convert JSON string to list of dicts
df['reviews_data'] = df['reviews_data'].apply(lambda x: json.loads(x) if pd.notnull(x) else [])

# Expand each list of reviews into separate rows
df_exploded = df.explode('reviews_data', ignore_index=True)

# Convert the dictionary in 'reviews' column into separate columns
df_reviews = pd.concat(
    [df_exploded.drop(columns=['reviews_data']), df_exploded['reviews_data'].apply(pd.Series)],
    axis=1
)

# %%
# clear variable to free up memory
del rawdata_tourist_attraction 
del rawdata_restaurant
del rawdata_hotel
del df
del df_exploded
gc.collect()
# Out:
# 0

# %%
df_reviews.shape
# Out:
# (36530, 24)

# %%
df_reviews.columns
# Out:
# Index(['place_id', 'name', 'address', 'latitude', 'longitude', 'types',
#        'googleMapsUri', 'priceRange', 'rating', 'userRatingCount',
#        'operating_hours', 'extract_date', 'region', 'category', 'author_name',
#        'author_url', 'language', 'original_language', 'profile_photo_url',
#        'rating', 'relative_time_description', 'text', 'time', 'translated'],
#       dtype='object')

# %% [markdown]
# # 4. Create unique identifier for the dataset by combining place_id and author_id

# %%
df_reviews['author_url'].head()
# Out:
# 0    https://www.google.com/maps/contrib/106077561112931137265/reviews
# 1    https://www.google.com/maps/contrib/104120339735079568818/reviews
# 2    https://www.google.com/maps/contrib/114607057292660266052/reviews
# 3    https://www.google.com/maps/contrib/103490304563243170642/reviews
# 4    https://www.google.com/maps/contrib/114620491599698100119/reviews
# Name: author_url, dtype: object

# %%
# Extract author_id from author_url
df_reviews['author_id'] = df_reviews['author_url'].str.split('/').str[-2]
df_reviews['author_id'].head()
# Out:
# 0    106077561112931137265
# 1    104120339735079568818
# 2    114607057292660266052
# 3    103490304563243170642
# 4    114620491599698100119
# Name: author_id, dtype: object

# %%
# Verify author_id no null value
df_reviews['author_id'].isnull().sum()
# Out:
# np.int64(0)

# %%
# Create uniqueID by combining place_id with author_id
df_reviews["uniqueID"] = df_reviews["place_id"] + "_" + df_reviews["author_id"]
df_reviews["uniqueID"].head()
# Out:
# 0    ChIJoxNlLcpLzDERzE5fun6q7v0_106077561112931137265
# 1    ChIJoxNlLcpLzDERzE5fun6q7v0_104120339735079568818
# 2    ChIJoxNlLcpLzDERzE5fun6q7v0_114607057292660266052
# 3    ChIJoxNlLcpLzDERzE5fun6q7v0_103490304563243170642
# 4    ChIJoxNlLcpLzDERzE5fun6q7v0_114620491599698100119
# Name: uniqueID, dtype: object

# %% [markdown]
# # 5. Verify reviews language

# %%
df_reviews['original_language'].value_counts()
# Out:
# original_language
# en    36530
# Name: count, dtype: int64

# %%
df_reviews['language'].value_counts()
# Out:
# language
# en    36530
# Name: count, dtype: int64

# %%
df_reviews['translated'].value_counts()
# Out:
# translated
# False    36530
# Name: count, dtype: int64

# %% [markdown]
# <br> **Findings**: <br/>
# Since all values in original_language, language and translated column having same value, we will drop those columns

# %% [markdown]
# # 6. Drop unused columns and rename columns

# %%
df_reviews.columns
# Out:
# Index(['place_id', 'name', 'address', 'latitude', 'longitude', 'types',
#        'googleMapsUri', 'priceRange', 'rating', 'userRatingCount',
#        'operating_hours', 'extract_date', 'region', 'category', 'author_name',
#        'author_url', 'language', 'original_language', 'profile_photo_url',
#        'rating', 'relative_time_description', 'text', 'time', 'translated',
#        'author_id', 'uniqueID'],
#       dtype='object')

# %%
df_reviews = df_reviews.drop(columns=[
    'author_url', 
    'profile_photo_url', 
    'language', 
    'original_language', 
    'translated'
    ]
)

# %%
# Rename rating columns
# Find all columns named 'rating'
rating_indices = [i for i, col in enumerate(df_reviews.columns) if col == "rating"]

# Rename by index
df_reviews.columns.values[rating_indices[0]] = "place_overall_rating"
df_reviews.columns.values[rating_indices[1]] = "user_review_rating"

# Check result
print(df_reviews.columns)
# Out:
# Index(['place_id', 'name', 'address', 'latitude', 'longitude', 'types',
#        'googleMapsUri', 'priceRange', 'place_overall_rating',
#        'userRatingCount', 'operating_hours', 'extract_date', 'region',
#        'category', 'author_name', 'user_review_rating',
#        'relative_time_description', 'text', 'time', 'author_id', 'uniqueID'],
#       dtype='object')

# %% [markdown]
# # 7. Convert unix timestamp to human readable format

# %%
# COnvert unix ts to human readable format timestamp yyyy-mm-dd hh:mm:ss
df_reviews["timestamp"] = pd.to_datetime(df_reviews["time"], unit='s')
df_reviews.drop(columns=['relative_time_description', 'time'], inplace= True)
df_reviews["timestamp"].head()
# Out:
# 0   2025-04-29 23:57:15
# 1   2025-09-21 14:54:01
# 2   2025-09-07 03:59:09
# 3   2025-08-02 09:31:05
# 4   2025-04-27 08:45:35
# Name: timestamp, dtype: datetime64[ns]

# %% [markdown]
# # 8. Extract 'state' from 'address'

# %%
# Remove singapore and thailand data
df_reviews = df_reviews[~df_reviews["address"].str.contains("Singapore|Thailand|Indonesia")]

# %%
# Extract state from address using regex 
malaysia_states = [
    "Johor", "Kedah", "Kelantan", "Kuala Lumpur", "Perak", "Pahang", "Labuan",
    "Melaka", "Malacca","Negeri Sembilan", "Pulau Pinang", "Penang", "Pantai Batu Feringghi",
    "Kota Kinabalu", "Kudat", "Manukan Island", "Borneo", "Sipadan Island", "Sandakan", "Semporna", "Sabah",
    "Perlis", "Putrajaya", "Sarawak", "Selangor", "Terengganu"
]
regex_pattern = r'(' + '|'.join(malaysia_states) + r')'
df_reviews['state'] = df_reviews['address'].str.extract(regex_pattern, flags=re.IGNORECASE)


# Standardize State 
df_reviews['state'] = df_reviews['state'].str.title()
state_map = {
    "Malacca": "Melaka",
    "Pulau Pinang": "Penang",
    "Pantai Batu Feringghi": "Penang",
    "Kota Kinabalu": "Sabah",
    "Kudat": "Sabah",
    "Manukan Island": "Sabah",
    "Borneo": "Sabah",  
    "Sipadan Island": "Sabah",
    "Sandakan": "Sabah",
    "Semporna": "Sabah"
}
df_reviews['state'].replace(state_map, inplace=True)
df_reviews.drop(columns="region", inplace=True)

# Print outcome
df_reviews['state'].value_counts()
# Out:
# C:\Users\Ong Hui Ling\AppData\Local\Temp\ipykernel_14660\39156487.py:26: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_reviews['state'].replace(state_map, inplace=True)
# state
# Kuala Lumpur       4300
# Selangor           4140
# Perak              3455
# Johor              3010
# Penang             2875
# Pahang             2870
# Sabah              2705
# Kedah              2540
# Negeri Sembilan    2170
# Melaka             2120
# Sarawak            1895
# Terengganu         1315
# Kelantan           1150
# Putrajaya           990
# Perlis              485
# Labuan              270
# Name: count, dtype: int64

# %%
df_reviews['state'].isnull().sum()
# Out:
# np.int64(10)

# %%
null_state = df_reviews[df_reviews['state'].isnull()]
null_state['name']
# Out:
# 8555            Taman Negeri Perlis
# 8556            Taman Negeri Perlis
# 8557            Taman Negeri Perlis
# 8558            Taman Negeri Perlis
# 8559            Taman Negeri Perlis
# 9760    Sipadan Kapalai Dive Resort
# 9761    Sipadan Kapalai Dive Resort
# 9762    Sipadan Kapalai Dive Resort
# 9763    Sipadan Kapalai Dive Resort
# 9764    Sipadan Kapalai Dive Resort
# Name: name, dtype: object

# %%
# handle special case
df_reviews['state'] = np.where(
    (df_reviews['state'].isnull()) & (df_reviews["name"] == "Taman Negeri Perlis"),  
    "Perlis",                 
    df_reviews['state']       
)

df_reviews['state'] = np.where(
    (df_reviews['state'].isnull()) & (df_reviews["name"] == "Sipadan Kapalai Dive Resort"),  
    "Sabah",                 
    df_reviews['state']       
)

# %%
df_reviews['state'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # 9. Check for null value

# %%
df_reviews.isnull().sum()
# Out:
# place_id                    0
# name                        0
# address                     0
# latitude                    0
# longitude                   0
# types                       0
# googleMapsUri               0
# priceRange              22315
# place_overall_rating        0
# userRatingCount             0
# operating_hours          4095
# extract_date                0
# category                    0
# author_name                 0
# user_review_rating          0
# text                        0
# author_id                   0
# uniqueID                    0
# timestamp                   0
# state                       0
# dtype: int64

# %%
not_null_df = df_reviews[~df_reviews['priceRange'].isnull()]

# %%
not_null_df['category'].value_counts()
# Out:
# category
# Restaurant             13815
# Tourist Attractions      155
# Hotel                     15
# Name: count, dtype: int64

# %%
df_reviews['category'].value_counts()
# Out:
# category
# Restaurant             20855
# Tourist Attractions    10235
# Hotel                   5210
# Name: count, dtype: int64

# %% [markdown]
# <br> **Findings**:<br/>
# priceRange columns are mainly for Restaurant data, will clean that when doing analysis for each category

# %%
df_reviews.columns
# Out:
# Index(['place_id', 'name', 'address', 'latitude', 'longitude', 'types',
#        'googleMapsUri', 'priceRange', 'place_overall_rating',
#        'userRatingCount', 'operating_hours', 'extract_date', 'category',
#        'author_name', 'user_review_rating', 'text', 'author_id', 'uniqueID',
#        'timestamp', 'state'],
#       dtype='object')

# %% [markdown]
# # 10. Extract 'category' from 'types'
# Establish 4 main category
# 1. Tourist attraction
# 2. Mall
# 3. Hotel
# 4. Restaurant

# %%
df_reviews['types'].unique()
# Out:
# array(["['establishment', 'park', 'point_of_interest', 'tourist_attraction']",
#        "['establishment', 'point_of_interest', 'tourist_attraction']",
#        "['establishment', 'mosque', 'place_of_worship', 'point_of_interest', 'tourist_attraction']",
#        "['establishment', 'point_of_interest', 'shopping_mall']",
#        "['amusement_park', 'establishment', 'park', 'point_of_interest', 'tourist_attraction', 'zoo']",
#        "['amusement_park', 'establishment', 'point_of_interest', 'tourist_attraction']",
#        "['establishment', 'park', 'point_of_interest']",
#        "['amusement_park', 'establishment', 'point_of_interest']",
#        "['establishment', 'park', 'point_of_interest', 'shopping_mall']",
#        "['establishment', 'museum', 'point_of_interest', 'tourist_attraction']",
#        "['church', 'establishment', 'place_of_worship', 'point_of_interest', 'tourist_attraction']",
#        "['establishment', 'park', 'point_of_interest', 'tourist_attraction', 'zoo']",
#        "['amusement_park', 'bar', 'establishment', 'food', 'lodging', 'point_of_interest', 'restaurant']",
#        "['establishment', 'food', 'grocery_or_supermarket', 'point_of_interest', 'shopping_mall', 'store', 'supermarket']",
#        "['establishment', 'point_of_interest']",
#        "['art_gallery', 'establishment', 'home_goods_store', 'museum', 'point_of_interest', 'store', 'tourist_attraction']",
#        "['bakery', 'establishment', 'food', 'grocery_or_supermarket', 'point_of_interest', 'shopping_mall', 'store', 'supermarket']",
#        "['establishment', 'point_of_interest', 'tourist_attraction', 'zoo']",
#        "['establishment', 'museum', 'point_of_interest']",
#        "['amusement_park', 'establishment', 'park', 'point_of_interest', 'tourist_attraction']",
#        "['establishment', 'place_of_worship', 'point_of_interest', 'tourist_attraction']",
#        "['establishment', 'point_of_interest', 'travel_agency']",
#        "['church', 'establishment', 'place_of_worship', 'point_of_interest']",
#        "['art_gallery', 'establishment', 'museum', 'point_of_interest', 'tourist_attraction']",
#        "['aquarium', 'establishment', 'point_of_interest', 'tourist_attraction']",
#        "['establishment', 'food', 'point_of_interest', 'restaurant']",
#        "['amusement_park', 'aquarium', 'bar', 'establishment', 'food', 'museum', 'night_club', 'point_of_interest', 'restaurant', 'spa', 'tourist_attraction']",
#        "['establishment', 'food', 'museum', 'parking', 'point_of_interest', 'store', 'tourist_attraction']",
#        "['establishment', 'mosque', 'place_of_worship', 'point_of_interest']",
#        "['establishment', 'park', 'point_of_interest', 'travel_agency']",
#        "['establishment', 'food', 'grocery_or_supermarket', 'point_of_interest', 'store', 'supermarket']",
#        "['establishment', 'landmark', 'park', 'point_of_interest', 'tourist_attraction']",
#        "['amusement_park', 'establishment', 'lodging', 'point_of_interest', 'tourist_attraction']",
#        "['amusement_park', 'establishment', 'museum', 'point_of_interest']",
#        "['casino', 'establishment', 'lodging', 'point_of_interest', 'tourist_attraction']",
#        "['establishment', 'hindu_temple', 'place_of_worship', 'point_of_interest', 'tourist_attraction']",
#        "['establishment', 'natural_feature']",
#        "['establishment', 'point_of_interest', 'shopping_mall', 'store']",
#        "['establishment', 'point_of_interest', 'shopping_mall', 'tourist_attraction']",
#        "['establishment', 'pet_store', 'point_of_interest', 'store']",
#        "['establishment', 'furniture_store', 'home_goods_store', 'point_of_interest', 'shopping_mall', 'store']",
#        "['establishment', 'point_of_interest', 'zoo']",
#        "['establishment', 'hindu_temple', 'place_of_worship', 'point_of_interest']",
#        "['art_gallery', 'establishment', 'point_of_interest', 'tourist_attraction']",
#        "['establishment', 'park', 'point_of_interest', 'zoo']",
#        "['establishment', 'point_of_interest', 'tourist_attraction', 'travel_agency']",
#        "['campground', 'establishment', 'lodging', 'park', 'point_of_interest']",
#        "['establishment', 'point_of_interest', 'tourist_attraction', 'travel_agency', 'zoo']",
#        "['establishment', 'lodging', 'point_of_interest']",
#        "['aquarium', 'establishment', 'general_contractor', 'pet_store', 'point_of_interest', 'store', 'zoo']",
#        "['amusement_park', 'establishment', 'food', 'lodging', 'point_of_interest', 'restaurant', 'spa']",
#        "['aquarium', 'establishment', 'pet_store', 'point_of_interest', 'store']",
#        "['amusement_park', 'establishment', 'lodging', 'point_of_interest']",
#        "['aquarium', 'establishment', 'food', 'pet_store', 'point_of_interest', 'store']",
#        "['establishment', 'movie_theater', 'point_of_interest', 'shopping_mall']",
#        "['establishment', 'food', 'point_of_interest']",
#        "['establishment', 'museum', 'place_of_worship', 'point_of_interest', 'tourist_attraction']",
#        "['establishment', 'mosque', 'place_of_worship', 'point_of_interest', 'tourist_attraction', 'travel_agency']",
#        "['department_store', 'establishment', 'food', 'grocery_or_supermarket', 'point_of_interest', 'shopping_mall', 'store', 'supermarket']",
#        "['establishment', 'food', 'park', 'point_of_interest', 'store', 'tourist_attraction']",
#        "['establishment', 'food', 'point_of_interest', 'store', 'tourist_attraction']",
#        "['art_gallery', 'establishment', 'museum', 'point_of_interest']",
#        "['establishment', 'food', 'point_of_interest', 'restaurant', 'tourist_attraction']",
#        "['department_store', 'establishment', 'point_of_interest', 'shopping_mall', 'store']",
#        "['aquarium', 'establishment', 'point_of_interest']",
#        "['establishment', 'museum', 'point_of_interest', 'tourist_attraction', 'travel_agency']",
#        "['establishment', 'point_of_interest', 'store']",
#        "['establishment', 'food', 'lodging', 'point_of_interest', 'restaurant', 'travel_agency']",
#        "['establishment', 'food', 'point_of_interest', 'restaurant', 'shopping_mall']",
#        "['establishment', 'food', 'grocery_or_supermarket', 'point_of_interest', 'shopping_mall', 'store']",
#        "['campground', 'establishment', 'lodging', 'park', 'point_of_interest', 'tourist_attraction']",
#        "['clothing_store', 'establishment', 'point_of_interest', 'store']",
#        "['establishment', 'health', 'point_of_interest', 'tourist_attraction']",
#        "['establishment', 'food', 'point_of_interest', 'tourist_attraction']",
#        "['amusement_park', 'cafe', 'establishment', 'food', 'point_of_interest', 'store']",
#        "['establishment', 'food', 'point_of_interest', 'restaurant', 'store', 'tourist_attraction']",
#        "['establishment', 'food', 'pet_store', 'point_of_interest', 'store']",
#        "['establishment', 'point_of_interest', 'university']",
#        "['aquarium', 'establishment', 'museum', 'point_of_interest', 'tourist_attraction']",
#        "['establishment', 'place_of_worship', 'point_of_interest']",
#        "['establishment', 'food', 'park', 'point_of_interest', 'restaurant', 'store', 'tourist_attraction', 'zoo']",
#        "['amusement_park', 'clothing_store', 'establishment', 'food', 'point_of_interest', 'store', 'tourist_attraction']",
#        "['establishment', 'lodging', 'point_of_interest', 'shopping_mall']",
#        "['department_store', 'establishment', 'point_of_interest', 'store']",
#        "['establishment', 'food', 'grocery_or_supermarket', 'movie_theater', 'point_of_interest', 'store', 'supermarket', 'tourist_attraction']",
#        "['amusement_park', 'establishment', 'park', 'point_of_interest']",
#        "['establishment', 'food', 'point_of_interest', 'shopping_mall', 'store']",
#        "['clothing_store', 'department_store', 'electronics_store', 'establishment', 'food', 'grocery_or_supermarket', 'point_of_interest', 'shopping_mall', 'store', 'supermarket']",
#        "['establishment', 'point_of_interest', 'store', 'tourist_attraction']",
#        "['bar', 'establishment', 'food', 'lodging', 'park', 'point_of_interest', 'restaurant']",
#        "['establishment', 'point_of_interest', 'shopping_mall', 'store', 'tourist_attraction']",
#        "['clothing_store', 'establishment', 'museum', 'point_of_interest', 'store']",
#        "['establishment', 'food', 'lodging', 'point_of_interest', 'store', 'tourist_attraction']",
#        "['bakery', 'cafe', 'establishment', 'food', 'health', 'lodging', 'point_of_interest', 'store']",
#        "['cafe', 'establishment', 'food', 'lodging', 'point_of_interest']",
#        "['electronics_store', 'establishment', 'point_of_interest', 'shopping_mall', 'store']",
#        "['establishment', 'museum', 'point_of_interest', 'store', 'tourist_attraction']",
#        "['establishment', 'food', 'point_of_interest', 'store']",
#        "['book_store', 'establishment', 'point_of_interest', 'shopping_mall', 'store']",
#        "['establishment', 'lodging', 'point_of_interest', 'spa']",
#        "['bar', 'establishment', 'food', 'point_of_interest', 'restaurant']",
#        "['establishment', 'food', 'lodging', 'movie_theater', 'point_of_interest', 'restaurant', 'shopping_mall', 'store']",
#        "['amusement_park', 'establishment', 'point_of_interest', 'spa', 'tourist_attraction']",
#        "['electronics_store', 'establishment', 'food', 'grocery_or_supermarket', 'home_goods_store', 'point_of_interest', 'shopping_mall', 'store']",
#        "['cafe', 'establishment', 'food', 'museum', 'point_of_interest', 'store']",
#        "['amusement_park', 'establishment', 'food', 'hair_care', 'health', 'point_of_interest', 'shopping_mall']",
#        "['establishment', 'health', 'pharmacy', 'point_of_interest', 'store']",
#        "['cafe', 'establishment', 'food', 'point_of_interest']",
#        "['casino', 'establishment', 'point_of_interest']",
#        "['cafe', 'establishment', 'food', 'museum', 'point_of_interest', 'store', 'tourist_attraction']",
#        "['establishment', 'general_contractor', 'point_of_interest', 'tourist_attraction']",
#        "['cafe', 'establishment', 'food', 'park', 'point_of_interest', 'restaurant', 'store', 'tourist_attraction']",
#        "['cafe', 'establishment', 'food', 'point_of_interest', 'store', 'tourist_attraction']",
#        "['establishment', 'lodging', 'point_of_interest', 'rv_park']",
#        "['establishment', 'point_of_interest', 'transit_station']",
#        "['establishment', 'food', 'movie_theater', 'point_of_interest', 'restaurant', 'shopping_mall']",
#        "['electronics_store', 'establishment', 'point_of_interest', 'store']",
#        "['establishment', 'point_of_interest', 'veterinary_care']",
#        "['amusement_park', 'establishment', 'food', 'point_of_interest', 'restaurant', 'tourist_attraction']",
#        "['campground', 'establishment', 'food', 'lodging', 'park', 'point_of_interest', 'restaurant']",
#        "['establishment', 'pet_store', 'point_of_interest', 'store', 'zoo']",
#        "['art_gallery', 'establishment', 'point_of_interest']",
#        "['establishment', 'lodging', 'point_of_interest', 'tourist_attraction']",
#        "['electronics_store', 'establishment', 'furniture_store', 'hardware_store', 'home_goods_store', 'point_of_interest', 'shopping_mall', 'store']",
#        "['establishment', 'food', 'lodging', 'park', 'point_of_interest', 'restaurant', 'rv_park']",
#        "['amusement_park', 'establishment', 'food', 'point_of_interest', 'restaurant']",
#        "['amusement_park', 'establishment', 'lodging', 'point_of_interest', 'spa']",
#        "['establishment', 'lodging', 'park', 'point_of_interest', 'zoo']",
#        "['establishment', 'landmark', 'point_of_interest', 'tourist_attraction']",
#        "['establishment', 'lodging', 'park', 'point_of_interest']",
#        "['cafe', 'establishment', 'food', 'lodging', 'point_of_interest', 'restaurant', 'store', 'tourist_attraction']",
#        "['campground', 'establishment', 'health', 'lodging', 'park', 'point_of_interest']",
#        "['establishment', 'food', 'lodging', 'park', 'point_of_interest', 'restaurant']",
#        "['establishment', 'food', 'lodging', 'point_of_interest', 'restaurant']",
#        "['establishment', 'lodging', 'point_of_interest', 'real_estate_agency']",
#        "['clothing_store', 'establishment', 'home_goods_store', 'point_of_interest', 'shopping_mall', 'store']",
#        "['establishment', 'food', 'point_of_interest', 'shopping_mall']",
#        "['establishment', 'food', 'park', 'point_of_interest', 'tourist_attraction', 'travel_agency']",
#        "['cafe', 'establishment', 'food', 'point_of_interest', 'zoo']",
#        "['department_store', 'establishment', 'food', 'grocery_or_supermarket', 'point_of_interest', 'store', 'supermarket']",
#        "['cafe', 'establishment', 'food', 'point_of_interest', 'store']",
#        "['establishment', 'food', 'grocery_or_supermarket', 'home_goods_store', 'point_of_interest', 'store']",
#        "['establishment', 'food', 'grocery_or_supermarket', 'point_of_interest', 'store']",
#        "['clothing_store', 'establishment', 'point_of_interest', 'store', 'tourist_attraction']",
#        "['establishment', 'movie_theater', 'point_of_interest']",
#        "['establishment', 'food', 'lodging', 'park', 'point_of_interest', 'restaurant', 'tourist_attraction']",
#        "['establishment', 'liquor_store', 'point_of_interest', 'store']",
#        "['airport', 'establishment', 'point_of_interest']",
#        "['establishment', 'hardware_store', 'home_goods_store', 'point_of_interest', 'store']",
#        "['establishment', 'point_of_interest', 'spa']",
#        "['establishment', 'lodging', 'point_of_interest', 'store']",
#        "['bakery', 'establishment', 'food', 'lodging', 'point_of_interest', 'store']",
#        "['bowling_alley', 'establishment', 'point_of_interest']",
#        "['establishment', 'food', 'point_of_interest', 'tourist_attraction', 'travel_agency']",
#        "['clothing_store', 'establishment', 'food', 'grocery_or_supermarket', 'movie_theater', 'point_of_interest', 'shopping_mall', 'store', 'supermarket']",
#        "['cafe', 'establishment', 'food', 'grocery_or_supermarket', 'point_of_interest', 'restaurant', 'shopping_mall', 'store', 'supermarket']",
#        "['bar', 'establishment', 'food', 'point_of_interest', 'restaurant', 'tourist_attraction']",
#        "['establishment', 'movie_theater', 'point_of_interest', 'store']",
#        "['bakery', 'bar', 'establishment', 'food', 'point_of_interest', 'restaurant', 'store']",
#        "['bar', 'cafe', 'establishment', 'food', 'point_of_interest']",
#        "['bar', 'establishment', 'point_of_interest']",
#        "['bar', 'establishment', 'food', 'night_club', 'point_of_interest', 'restaurant']",
#        "['cafe', 'establishment', 'food', 'point_of_interest', 'restaurant']",
#        "['establishment', 'food', 'meal_takeaway', 'point_of_interest', 'restaurant', 'store']",
#        "['bakery', 'establishment', 'food', 'point_of_interest', 'restaurant', 'store']",
#        "['cafe', 'establishment', 'food', 'point_of_interest', 'restaurant', 'store']",
#        "['bar', 'cafe', 'establishment', 'food', 'point_of_interest', 'restaurant']",
#        "['cafe', 'establishment', 'food', 'meal_takeaway', 'point_of_interest', 'restaurant']",
#        "['cafe', 'establishment', 'food', 'meal_delivery', 'meal_takeaway', 'point_of_interest', 'restaurant', 'store']",
#        "['bakery', 'cafe', 'establishment', 'food', 'point_of_interest', 'store']",
#        "['bakery', 'cafe', 'establishment', 'food', 'point_of_interest', 'restaurant', 'store']",
#        "['establishment', 'food', 'meal_delivery', 'point_of_interest', 'restaurant']",
#        "['bar', 'establishment', 'food', 'movie_theater', 'point_of_interest', 'restaurant']",
#        "['establishment', 'food', 'point_of_interest', 'restaurant', 'store']",
#        "['bar', 'establishment', 'food', 'meal_delivery', 'night_club', 'point_of_interest', 'restaurant']",
#        "['bar', 'establishment', 'food', 'meal_takeaway', 'point_of_interest', 'restaurant']",
#        "['bar', 'establishment', 'food', 'night_club', 'point_of_interest']",
#        "['bakery', 'cafe', 'establishment', 'food', 'grocery_or_supermarket', 'point_of_interest', 'restaurant', 'store']",
#        "['establishment', 'food', 'grocery_or_supermarket', 'museum', 'point_of_interest', 'restaurant', 'store']",
#        "['establishment', 'food', 'point_of_interest', 'restaurant', 'tourist_attraction', 'travel_agency']",
#        "['bar', 'cafe', 'establishment', 'food', 'point_of_interest', 'restaurant', 'store']",
#        "['bar', 'establishment', 'food', 'liquor_store', 'point_of_interest', 'restaurant', 'store']",
#        "['bar', 'cafe', 'establishment', 'food', 'night_club', 'point_of_interest', 'restaurant']",
#        "['establishment', 'food', 'liquor_store', 'point_of_interest', 'restaurant', 'store']",
#        "['establishment', 'food', 'meal_takeaway', 'point_of_interest', 'restaurant']",
#        "['establishment', 'food', 'park', 'point_of_interest', 'restaurant']",
#        "['bar', 'establishment', 'food', 'point_of_interest']",
#        "['establishment', 'food', 'grocery_or_supermarket', 'meal_takeaway', 'point_of_interest', 'restaurant', 'store']",
#        "['establishment', 'food', 'parking', 'point_of_interest', 'restaurant']",
#        "['bar', 'establishment', 'night_club', 'point_of_interest']",
#        "['cafe', 'establishment', 'food', 'lodging', 'point_of_interest', 'restaurant', 'store']",
#        "['bar', 'cafe', 'establishment', 'food', 'liquor_store', 'point_of_interest', 'restaurant', 'store']",
#        "['establishment', 'food', 'night_club', 'point_of_interest', 'restaurant']",
#        "['art_gallery', 'cafe', 'establishment', 'food', 'point_of_interest', 'restaurant']",
#        "['bar', 'cafe', 'establishment', 'food', 'point_of_interest', 'restaurant', 'tourist_attraction']",
#        "['bakery', 'bar', 'cafe', 'establishment', 'food', 'point_of_interest', 'restaurant', 'store']",
#        "['art_gallery', 'establishment', 'food', 'point_of_interest', 'restaurant']",
#        "['establishment', 'food', 'grocery_or_supermarket', 'point_of_interest', 'restaurant', 'store']",
#        "['book_store', 'cafe', 'establishment', 'food', 'point_of_interest', 'store']",
#        "['cafe', 'establishment', 'food', 'park', 'point_of_interest', 'restaurant']",
#        "['bar', 'cafe', 'establishment', 'food', 'point_of_interest', 'store']",
#        "['bar', 'cafe', 'establishment', 'food', 'liquor_store', 'point_of_interest', 'store']",
#        "['bar', 'cafe', 'establishment', 'food', 'meal_takeaway', 'night_club', 'point_of_interest', 'restaurant']",
#        "['bar', 'establishment', 'food', 'point_of_interest', 'restaurant', 'store', 'tourist_attraction']",
#        "['cafe', 'establishment', 'food', 'lodging', 'point_of_interest', 'restaurant']",
#        "['bar', 'cafe', 'establishment', 'food', 'night_club', 'point_of_interest', 'restaurant', 'store']",
#        "['clothing_store', 'establishment', 'health', 'point_of_interest', 'store']",
#        "['cafe', 'establishment', 'food', 'general_contractor', 'point_of_interest', 'restaurant', 'store']",
#        "['bar', 'cafe', 'establishment', 'food', 'meal_delivery', 'point_of_interest', 'restaurant']",
#        "['bar', 'cafe', 'establishment', 'food', 'meal_takeaway', 'point_of_interest', 'restaurant']",
#        "['bakery', 'cafe', 'establishment', 'food', 'meal_takeaway', 'point_of_interest', 'restaurant', 'store']",
#        "['bar', 'cafe', 'establishment', 'food', 'night_club', 'point_of_interest']",
#        "['clothing_store', 'establishment', 'food', 'point_of_interest', 'restaurant', 'store']",
#        "['bakery', 'establishment', 'food', 'point_of_interest', 'store']",
#        "['bar', 'establishment', 'food', 'lodging', 'night_club', 'point_of_interest', 'restaurant']",
#        "['cafe', 'establishment', 'food', 'point_of_interest', 'restaurant', 'tourist_attraction']",
#        "['establishment', 'food', 'home_goods_store', 'point_of_interest', 'store']",
#        "['bakery', 'bar', 'establishment', 'food', 'grocery_or_supermarket', 'night_club', 'point_of_interest', 'restaurant', 'store']",
#        "['bicycle_store', 'cafe', 'establishment', 'food', 'point_of_interest', 'store']",
#        "['bar', 'clothing_store', 'establishment', 'food', 'lodging', 'point_of_interest', 'restaurant', 'store']",
#        "['cafe', 'establishment', 'food', 'meal_takeaway', 'point_of_interest', 'restaurant', 'store']",
#        "['cafe', 'establishment', 'food', 'lodging', 'point_of_interest', 'travel_agency']",
#        "['establishment', 'finance', 'general_contractor', 'lodging', 'point_of_interest']",
#        "['cafe', 'establishment', 'food', 'lodging', 'point_of_interest', 'real_estate_agency', 'restaurant', 'spa', 'travel_agency']",
#        "['bar', 'establishment', 'food', 'lodging', 'point_of_interest', 'restaurant']",
#        "['establishment', 'food', 'gym', 'health', 'lodging', 'point_of_interest', 'restaurant', 'spa']",
#        "['establishment', 'food', 'lodging', 'point_of_interest', 'restaurant', 'spa']",
#        "['establishment', 'health', 'lodging', 'point_of_interest']",
#        "['campground', 'establishment', 'health', 'lodging', 'park', 'point_of_interest', 'spa']",
#        "['establishment', 'food', 'lodging', 'point_of_interest', 'restaurant', 'zoo']",
#        "['clothing_store', 'establishment', 'lodging', 'point_of_interest', 'store']",
#        "['establishment', 'food', 'health', 'lodging', 'point_of_interest', 'restaurant']",
#        "['establishment', 'lodging', 'park', 'point_of_interest', 'travel_agency']",
#        "['bar', 'cafe', 'establishment', 'food', 'lodging', 'point_of_interest', 'restaurant']",
#        "['bar', 'cafe', 'establishment', 'food', 'lodging', 'point_of_interest']",
#        "['establishment', 'gym', 'health', 'lodging', 'point_of_interest']",
#        "['establishment', 'lodging', 'point_of_interest', 'storage']",
#        "['establishment', 'lodging', 'point_of_interest', 'travel_agency']",
#        "['establishment', 'health', 'lodging', 'point_of_interest', 'spa']",
#        "['establishment', 'food', 'lodging', 'park', 'point_of_interest', 'restaurant', 'spa']",
#        "['bar', 'cafe', 'establishment', 'food', 'lodging', 'night_club', 'point_of_interest', 'restaurant']",
#        "['establishment', 'food', 'lodging', 'point_of_interest', 'restaurant', 'tourist_attraction']",
#        "['establishment', 'general_contractor', 'point_of_interest']",
#        "['establishment', 'lodging', 'point_of_interest', 'school', 'travel_agency']"],
#       dtype=object)

# %%
# Apply ast.literal_eval to each string to safely convert it to a real list
# We use .drop_duplicates() first so we only process the unique strings
list_series = df_reviews['types'].drop_duplicates().apply(ast.literal_eval)

# Explode the lists and get uniques
unique_words = list_series.explode().unique()
print(unique_words)
# Out:
# ['establishment' 'park' 'point_of_interest' 'tourist_attraction' 'mosque'
#  'place_of_worship' 'shopping_mall' 'amusement_park' 'zoo' 'museum'
#  'church' 'bar' 'food' 'lodging' 'restaurant' 'grocery_or_supermarket'
#  'store' 'supermarket' 'art_gallery' 'home_goods_store' 'bakery'
#  'travel_agency' 'aquarium' 'night_club' 'spa' 'parking' 'landmark'
#  'casino' 'hindu_temple' 'natural_feature' 'pet_store' 'furniture_store'
#  'campground' 'general_contractor' 'movie_theater' 'department_store'
#  'clothing_store' 'health' 'cafe' 'university' 'electronics_store'
#  'book_store' 'hair_care' 'pharmacy' 'rv_park' 'transit_station'
#  'veterinary_care' 'hardware_store' 'real_estate_agency' 'liquor_store'
#  'airport' 'bowling_alley' 'meal_takeaway' 'meal_delivery' 'bicycle_store'
#  'finance' 'gym' 'storage' 'school']

# %% [markdown]
# <b> Findings: <br/>
# We will use the unique tag from types as the checkbox/ filter for tourism recommendation algorithm

# %%
# Explode the lists and then get the value counts
word_counts = list_series.explode().value_counts()
print(word_counts)
# Out:
# types
# establishment             244
# point_of_interest         243
# food                      133
# store                      94
# restaurant                 83
# tourist_attraction         61
# lodging                    57
# cafe                       48
# bar                        37
# park                       29
# shopping_mall              27
# grocery_or_supermarket     18
# amusement_park             18
# museum                     16
# travel_agency              15
# night_club                 13
# spa                        12
# zoo                        12
# bakery                     12
# health                     12
# clothing_store             11
# meal_takeaway              10
# place_of_worship           10
# supermarket                 9
# home_goods_store            8
# movie_theater               8
# art_gallery                 7
# aquarium                    7
# pet_store                   6
# liquor_store                5
# department_store            5
# electronics_store           5
# general_contractor          5
# campground                  5
# meal_delivery               4
# mosque                      3
# landmark                    2
# church                      2
# parking                     2
# book_store                  2
# furniture_store             2
# hindu_temple                2
# casino                      2
# hardware_store              2
# gym                         2
# real_estate_agency          2
# rv_park                     2
# hair_care                   1
# university                  1
# natural_feature             1
# veterinary_care             1
# airport                     1
# pharmacy                    1
# transit_station             1
# bowling_alley               1
# bicycle_store               1
# finance                     1
# storage                     1
# school                      1
# Name: count, dtype: int64

# %%
def categorize_reviews_priority(df_reviews):
    """
    Categorizes reviews with priority: tourist_attraction > mall > hotel > restaurant
    Maintains original types for recommendation engine
    """
    
    # 1. PRIORITY ORDER (Highest to Lowest)
    PRIORITY_ORDER = [
        "tourist_attraction",  # Highest priority - if venue has tourist_attraction, it's primary
        "mall",                # Second priority  
        "hotel",               # Third priority
        "restaurant"           # Lowest priority
    ]
    
    # 2. CATEGORY KEYWORDS
    categories = {
        "tourist_attraction": [
            "tourist_attraction", "amusement_park", "museum", "park", "zoo", 
            "aquarium", "art_gallery", "landmark", "natural_feature", "campground",
            "mosque", "place_of_worship", "hindu_temple", "church" , "travel_agency",
            "university"
        ],
        "mall": [
            "shopping_mall", "department_store", "store", "movie_theater", "casino", "bowling_alley"
        ],
        "hotel": [
            "lodging", "hotel", "rv_park", "spa"
        ],
        "restaurant": [
            "restaurant", "cafe", "bakery", "food", "bar", "night_club"
        ]
    }
    
    # 3. SUBCATEGORIES (Your excellent structure)
    subcategories = {
        "tourist_attraction": {
            "museum_gallery": ["museum", "art_gallery"],
            "park_nature": ["park", "natural_feature", "campground"],
            "amusement": ["amusement_park", "zoo", "aquarium"],
            "landmark": ["landmark"],
            "religious": ["mosque", "place_of_worship", "hindu_temple", "church"]
        },
        "mall": {
            "shopping_mall": ["shopping_mall"],
            "department_store": ["department_store"],
            "entertainment_mall": ["movie_theater", "bowling_alley"]  
        },
        "hotel": {
            "hotel": ["lodging", "hotel"],
            "resort": ["rv_park", "spa", "gym"] 
        },
        "restaurant": {
            "cafe_bakery": ["cafe", "bakery"],
            "bar_nightlife": ["bar", "night_club"],
            "restaurant": ["restaurant"]
        }
    }
    
    # 4. CREATE PRIORITY LOOKUP MAP
    priority_lookup = {}
    for priority_level, category_name in enumerate(PRIORITY_ORDER):
        for keyword in categories[category_name]:
            priority_lookup[keyword] = (priority_level, category_name)
    
    # 5. MAIN CATEGORY FUNCTION (Priority-Based)
    def get_priority_main_category(types_string):
        """
        Returns the highest priority category based on types
        """
        try:
            types_list = ast.literal_eval(types_string)
            if not isinstance(types_list, list):
                types_list = []
        except (ValueError, SyntaxError):
            types_list = []
        
        # Find the highest priority category (lowest priority number)
        highest_priority_found = float('inf')  # Start with worst possible
        best_category = "other"
        
        for type_name in types_list:
            if type_name in priority_lookup:
                priority_level, category = priority_lookup[type_name]
                if priority_level < highest_priority_found:
                    highest_priority_found = priority_level
                    best_category = category
                    # Early exit if we found the highest possible priority
                    if priority_level == 0:  # tourist_attraction (highest)
                        break
        
        return best_category
    
    # 6. SUBCATEGORY FUNCTION
    def get_subcategory(types_string, main_category):
        """
        Returns the most specific subcategory within the main category
        """
        try:
            types_list = ast.literal_eval(types_string)
            if not isinstance(types_list, list):
                types_list = []
        except (ValueError, SyntaxError):
            types_list = []
        
        if main_category not in subcategories:
            return "other"
        
        # Check each subcategory in order (first match wins)
        for sub_cat, keywords in subcategories[main_category].items():
            if any(keyword in types_list for keyword in keywords):
                return sub_cat
        
        # Default subcategory if no specific match
        return f"{main_category}_general"
    
    # 7. APPLY TO DATAFRAME
    print("Applying priority-based categorization...")
    
    # Main category (priority-based)
    df_reviews['main_category'] = df_reviews['types'].apply(get_priority_main_category)
    
    # Subcategory (within main category)
    df_reviews['sub_category'] = df_reviews.apply(
        lambda row: get_subcategory(row['types'], row['main_category']), 
        axis=1
    )
    
    return df_reviews

# %%
# Run the categorization
df_reviews = categorize_reviews_priority(df_reviews)
# Out:
# Applying priority-based categorization...

# %%
df_reviews['main_category'].value_counts()
# Out:
# main_category
# restaurant            19285
# tourist_attraction     6880
# hotel                  5865
# mall                   3830
# other                   440
# Name: count, dtype: int64

# %%
# Standardize the 'category' column values
df_reviews['category'].replace(
    {'Tourist Attractions': 'tourist_attraction',
     'Restaurant': 'restaurant',
     'Hotel': 'hotel'},
    inplace=True
)

# If 'main_category' is 'other', replace it with the corresponding 'category' value
df_reviews['main_category'] = np.where(
    df_reviews['main_category'] == "other",
    df_reviews['category'],
    df_reviews['main_category']
)

# Drop category column
df_reviews.drop(columns=['category'], inplace=True)
# Out:
# C:\Users\Ong Hui Ling\AppData\Local\Temp\ipykernel_14660\367582030.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_reviews['category'].replace(

# %%
df_reviews['main_category'].value_counts()
# Out:
# main_category
# restaurant            19330
# tourist_attraction     7235
# hotel                  5905
# mall                   3830
# Name: count, dtype: int64

# %%
df_reviews.to_pickle(r'C:\Users\Ong Hui Ling\Dropbox\PC\Documents\Github\AI-Driven-Tourism-Recommendation-System\Dataset\clean_data1.pkl')
